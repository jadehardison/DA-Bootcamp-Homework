# %% [markdown]
# Your objective is to build a Bubble Plot that showcases the relationship between four key variables:
#
# Average Fare ($) Per City
# Total Number of Rides Per City
# Total Number of Drivers Per City
# City Type (Urban, Suburban, Rural)
# In addition, you will be expected to produce the following three pie charts:
#
# % of Total Fares by City Type
# % of Total Rides by City Type
# % of Total Drivers by City Type

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ride_data = pd.read_csv("Resources/ride_data.csv")
city_data = pd.read_csv("Resources/city_data.csv")

# %%
city_data = pd.DataFrame(city_data)
city_data.head(20)
# Out:
#                     city  driver_count   type
# 0            Richardfort            38  Urban
# 1           Williamsstad            59  Urban
# 2            Port Angela            67  Urban
# 3             Rodneyfort            34  Urban
# 4            West Robert            39  Urban
# 5           West Anthony            70  Urban
# 6            West Angela            48  Urban
# 7          Martinezhaven            25  Urban
# 8              Karenberg            22  Urban
# 9            Barajasview            26  Urban
# 10            Robertport            12  Urban
# 11          Joneschester            39  Urban
# 12               Leahton            17  Urban
# 13  West Christopherberg            32  Urban
# 14               Johnton            27  Urban
# 15          Reynoldsfurt            67  Urban
# 16            Port David             7  Urban
# 17   New Kimberlyborough            33  Urban
# 18           Carriemouth            52  Urban
# 19             Rogerston            25  Urban

# %%
ride_data = pd.DataFrame(ride_data)
ride_data.head(20)
# Out:
#                    city             date   fare       ride_id
# 0    Lake Jonathanshire  1/14/2018 10:14  13.83  5.739410e+12
# 1    South Michelleport   3/4/2018 18:24  30.24  2.343910e+12
# 2    Port Samanthamouth   2/24/2018 4:29  33.44  2.005070e+12
# 3            Rodneyfort  2/10/2018 23:22  23.44  5.149250e+12
# 4            South Jack    3/6/2018 4:28  34.58  3.908450e+12
# 5          South Latoya  3/11/2018 12:26   9.52  1.995000e+12
# 6         New Paulville  2/27/2018 11:17  43.25  7.932080e+11
# 7          Simpsonburgh   4/26/2018 0:43  35.98  1.119540e+11
# 8       South Karenland    1/8/2018 3:28  35.09  7.995620e+12
# 9         North Jasmine    3/9/2018 6:26  42.81  5.327640e+12
# 10  New Kimberlyborough    2/7/2018 1:10   9.34  7.992780e+12
# 11          West Angela   1/12/2018 1:45  26.86  4.820050e+12
# 12           Rodneyfort   3/2/2018 18:03  44.26  2.494060e+12
# 13          West Angela  1/10/2018 12:17  12.74  2.108720e+12
# 14          Roberthaven   5/4/2018 14:48  25.66  1.026200e+12
# 15          North Jason  3/28/2018 22:28   9.19  7.007020e+12
# 16         Williamsview   1/3/2018 16:19  18.93  1.979490e+12
# 17              Leahton  2/26/2018 18:42   8.85  6.966670e+12
# 18         West Anthony    3/6/2018 2:27  10.02  9.396760e+12
# 19  New Kimberlyborough  4/25/2018 22:58  29.67  4.823570e+12

# %%
df = ride_data.merge(city_data, on="city", how="left")
df.head(10)
# Out:
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2018 10:14  13.83  5.739410e+12             5
# 1  South Michelleport   3/4/2018 18:24  30.24  2.343910e+12            72
# 2  Port Samanthamouth   2/24/2018 4:29  33.44  2.005070e+12            57
# 3          Rodneyfort  2/10/2018 23:22  23.44  5.149250e+12            34
# 4          South Jack    3/6/2018 4:28  34.58  3.908450e+12            46
# 5        South Latoya  3/11/2018 12:26   9.52  1.995000e+12            10
# 6       New Paulville  2/27/2018 11:17  43.25  7.932080e+11            44
# 7        Simpsonburgh   4/26/2018 0:43  35.98  1.119540e+11            21
# 8     South Karenland    1/8/2018 3:28  35.09  7.995620e+12             4
# 9       North Jasmine    3/9/2018 6:26  42.81  5.327640e+12            33
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban
# 5  Urban
# 6  Urban
# 7  Urban
# 8  Urban
# 9  Urban

# %%
# df = comb_df.groupby(['city', 'type'])
# df = pd.DataFrame(round(comb_df.mean(),2))
# df.reset_index(inplace=True)
# df()

df = pd.merge(city_data, ride_data, on='city', how='left')

df = df.groupby(['city', "type"])
df = pd.DataFrame(round(df.mean(),2))

df = df.reset_index()

df.head()
# Out:
#             city      type  driver_count   fare       ride_id
# 0    Amandaburgh     Urban            12  24.64  5.359336e+12
# 1    Barajasview     Urban            26  25.33  4.676968e+12
# 2  Barronchester  Suburban            11  36.42  4.460796e+12
# 3    Bethanyland  Suburban            22  32.96  5.842550e+12
# 4   Bradshawfurt     Rural             7  40.06  3.735292e+12

# %%
# Total number of rides per city
city_count = ride_data.copy()

city_count = city_count.groupby('city')['ride_id'].count()
city_count = pd.DataFrame(city_count)

city_count = city_count.reset_index()
city_count = city_count.rename(columns={'ride_id':'Total number of rides'})
city_count.head()
# Out:
#             city  Total number of rides
# 0    Amandaburgh                     18
# 1    Barajasview                     22
# 2  Barronchester                     16
# 3    Bethanyland                     18
# 4   Bradshawfurt                     10

# %%
# Final dataframe which contain city type, total number of rides, total drivers and average fare per city.
df = pd.merge(df,city_count, on='city')

df = df.loc[:,['city', 'type', 'Total number of rides', 'driver_count', 'fare',]]

df = pd.DataFrame(df)
df.rename(columns={'city':'City',
                   'type':'Types',
                   'fare':'Average fare',
                   'driver_count':'Total drivers'
                  })
# Out:
#                      City     Types  Total number of rides  Total drivers  \
# 0             Amandaburgh     Urban                     18             12
# 1             Barajasview     Urban                     22             26
# 2           Barronchester  Suburban                     16             11
# 3             Bethanyland  Suburban                     18             22
# 4            Bradshawfurt     Rural                     10              7
# 5             Brandonfort  Suburban                     19             10
# 6             Carriemouth     Urban                     27             52
# 7         Christopherfurt     Urban                     27             41
# 8             Colemanland  Suburban                     22             23
# 9               Davidfurt  Suburban                     17             23
# 10              Deanville     Urban                     19             49
# 11         East Aaronbury  Suburban                      9              7
# 12        East Danielview  Suburban                     17             22
# 13        East Kaylahaven     Urban                     29             65
# 14          East Kentstad  Suburban                     13             20
# 15         East Marymouth  Suburban                     27              5
# 16              Erikaland     Urban                     12             37
# 17              Garzaport     Rural                      3              7
# 18            Grahamburgh     Urban                     25             61
# 19              Grayville  Suburban                     15              2
# 20         Harringtonfort     Rural                      6              4
# 21            Huntermouth     Urban                     24             37
# 22            Hurleymouth     Urban                     28             36
# 23               Jerryton     Urban                     25             64
# 24            Jessicaport     Rural                      6              1
# 25                Johnton     Urban                     21             27
# 26           Joneschester     Urban                     25             39
# 27             Josephside  Suburban                     27             25
# 28             Justinberg     Urban                     30             39
# 29              Karenberg     Urban                     17             22
# ..                    ...       ...                    ...            ...
# 90          South Evanton     Urban                     31             11
# 91             South Jack     Urban                     19             46
# 92         South Jennifer     Rural                      7              7
# 93        South Karenland     Urban                     38              4
# 94           South Latoya     Urban                     19             10
# 95      South Marychester     Rural                      8              1
# 96     South Michelleport     Urban                     31             72
# 97          South Phillip     Urban                     31             38
# 98        South Saramouth     Rural                      4              7
# 99           South Teresa  Suburban                     22             21
# 100           Taylorhaven     Rural                      6              1
# 101          Valentineton     Urban                     22             45
# 102          Veronicaberg  Suburban                     17             20
# 103          Victoriaport  Suburban                     14             16
# 104           West Angela     Urban                     39             48
# 105          West Anthony     Urban                     30             70
# 106  West Christopherberg     Urban                     26             32
# 107         West Ericstad     Urban                     18             25
# 108          West Gabriel     Urban                     23             57
# 109           West Hannah  Suburban                     21             12
# 110          West Heather     Rural                      9              4
# 111            West Heidi     Urban                     28             28
# 112       West Josephberg     Urban                     26             45
# 113         West Kimmouth  Suburban                     20              4
# 114   West Patrickchester     Urban                     16             25
# 115           West Robert     Urban                     31             39
# 116      West Samuelburgh     Urban                     25             73
# 117       Williamsonville  Suburban                     14              2
# 118          Williamsstad     Urban                     23             59
# 119          Williamsview     Urban                     20             46
#
#      Average fare
# 0           24.64
# 1           25.33
# 2           36.42
# 3           32.96
# 4           40.06
# 5           35.44
# 6           28.31
# 7           24.50
# 8           30.89
# 9           32.00
# 10          25.84
# 11          25.66
# 12          31.56
# 13          23.76
# 14          29.82
# 15          30.84
# 16          24.91
# 17          24.12
# 18          25.22
# 19          27.76
# 20          33.47
# 21          28.99
# 22          25.89
# 23          25.65
# 24          36.01
# 25          26.79
# 26          22.29
# 27          32.86
# 28          23.69
# 29          26.34
# ..            ...
# 90          26.73
# 91          22.97
# 92          35.26
# 93          26.54
# 94          20.09
# 95          41.87
# 96          24.45
# 97          28.57
# 98          36.16
# 99          31.22
# 100         42.26
# 101         24.64
# 102         32.83
# 103         27.78
# 104         25.99
# 105         24.74
# 106         24.42
# 107         22.35
# 108         20.35
# 109         29.55
# 110         33.89
# 111         23.13
# 112         21.72
# 113         29.87
# 114         28.23
# 115         25.12
# 116         21.77
# 117         31.87
# 118         24.36
# 119         26.60
#
# [120 rows x 5 columns]

# %%
# create scatter plot: X axis: Total number of rides per city, Y axis: Average fares and city type plotted

u = df.type.str.count(r'Urban')
s = df.type.str.count(r'Suburban')
r = df.type.str.count(r'Rural')


x = (df['Total number of rides'] * u) 
y = (df['fare'] * u)

plt.scatter(x, y, alpha=0.7, c='lightcoral', edgecolors='coral', s = df['driver_count']*10, label="Urban", linewidths=2)


x = (df['Total number of rides'] * s)
y = (df['fare'] * s)

plt.scatter(x, y, alpha=0.7, c='lightskyblue', edgecolors='skyblue', s = df['driver_count']*10, label='Suburban', linewidths=2)


x = (df['Total number of rides'] * r)
y = (df['fare'] * r)

plt.scatter(x, y, alpha=0.7, c='gold', edgecolors='orange', s = df['driver_count']*10, label='Rural', linewidths=2)

# %%
# Total Ride Fare
grouped_cities = df.groupby(["type"])
sum_fare = grouped_cities.sum()

colors = ['gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1)
labels = ['Urban', 'Suburban', 'Rural']

total_fares = sum_fare[["fare"]]
total_fares['Total Fare'] = total_fares['fare']

total_fares.plot(kind='pie', y='Total Fare', explode=explode, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis("equal")
plt.show()
# Out:
# C:\Users\jadeh\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Total Rides
total_ride = grouped_cities.count()

colors = ['gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1)
labels = ['Urban', 'Suburban', 'Rural']

total_rides = total_ride[["city"]]
total_rides['Total Rides'] = total_rides['city']

total_rides.plot(kind='pie', y='Total Rides', explode=explode, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis("equal")
plt.show()
# Out:
# C:\Users\jadeh\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Total Drivers 
grouped_drivers = city_data.groupby(["type"])
sum_drive = grouped_drivers.sum()

colors = ['gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1)
labels = ['Urban', 'Suburban', 'Rural']

total_drivers = sum_drive[["driver_count"]]
total_drivers['Total Drivers'] = total_drivers['driver_count']

total_drivers.plot(kind='pie', y='Total Drivers', explode=explode, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis("equal")
plt.show()
